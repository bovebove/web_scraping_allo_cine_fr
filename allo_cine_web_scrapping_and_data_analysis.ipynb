# %% [markdown]
# # Web Scraping des informations sur les meilleurs films di site allocine

# %% [markdown]
# ## Importation des librairies nécessaires

# %%
# requests pour recupérer des pages depuis internet
import requests
# BeautifulSoup pour parcourir les pages HTML et y extraire les données recherchées 
from bs4 import BeautifulSoup 
# numpy et pandas pour collecter et traiter les données
import numpy as np
import pandas as pd

# %% [markdown]
# ### extraire les titres des films de la page 1

# %%
# on dééclare l'url de la page 1
url = 'https://www.allocine.fr/film/meilleurs/'
response = requests.get(url) 
soup=BeautifulSoup(response.text,'html.parser')
titres_balise=soup.find_all("a",{"class":"meta-title-link"})
titres=[x.get_text() for x in titres_balise]
titres
# Out:
# ['Forrest Gump',
#  'La Liste de Schindler',
#  'La Ligne verte',
#  '12 hommes en colère',
#  'Le Parrain',
#  'Les Evadés',
#  'Le Seigneur des anneaux : le retour du roi',
#  'Le Roi Lion',
#  "Vol au-dessus d'un nid de coucou",
#  'The Dark Knight, Le Chevalier Noir']

# %%
# extraire les resumés des films de la page 1
resume_balise=soup.find_all("div",{"class":"content-txt"})
resume=[x.get_text() for x in resume_balise]
resume
# Out:
# ["\n Quelques décennies d'histoire américaine, des années 1940 à la fin du XXème siècle, à travers le regard et l'étrange odyssée d'un homme simple et pur, Forrest Gump.\n",
#  "\nEvocation des années de guerre d'Oskar Schindler, industriel autrichien rentré à Cracovie en 1939 avec les troupes allemandes. Il va, tout au long de la guerre, protéger des juifs en les faisant travailler dans sa fabrique.\n",
#  '\nPaul Edgecomb, Gardien-chef du pénitencier de Cold Mountain en 1935, était chargé de veiller au bon déroulement des exécutions capitales. Parmi les prisonniers se trouvait un colosse du nom de John Coffey...\n',
#  "\nLors d'un procès, un juré émet l'hypothèse que l'homme qu'il doit juger n'est peut-être pas coupable. Il va tenter de convaincre les onze autres jurés.\n",
#  '\nEn 1945, à New York, les Corleone sont une des cinq familles de la mafia. Don Vito Corleone marie sa fille à un bookmaker. Sollozzo, "parrain" de la famille Tattaglia, propose à Don Vito une association dans le trafic de drogue...\n',
#  "\nCondamné à perpétuité pour le meurtre de sa femme et de son amant, un banquier s'accroche à l'espoir et se lie d'amitié avec un autre détenu pour survivre en prison.\n",
#  "\nTandis que les ténèbres se répandent sur la Terre du Milieu, Aragorn se révèle être l'héritier caché des rois antiques. Quant à Frodon, toujours tenté par l'Anneau, il voyage à travers les contrées ennemies, se reposant sur Sam et Gollum...\n",
#  '\nLe long combat de Simba le lionceau pour accéder à son rang de roi des animaux, après que le fourbe Scar, son oncle, a tué son père et pris sa place.\n',
#  "\nRebellion dans un hôpital psychiatrique à l'instigation d'un malade qui se révolte contre la dureté d'une infirmière.\n",
#  '\nBatman entreprend de démanteler les dernières organisations criminelles de Gotham. Mais il se heurte bientôt à un nouveau génie du crime qui répand la terreur et le chaos dans la ville : le Joker...\n']

# %%
# extraire les notes des films de la page 1
note_balise=soup.find_all("span",{"class":"stareval-note"})
note=[x.get_text() for x in note_balise]
note
# Out:
# ['2,6',
#  '4,6',
#  '--',
#  '4,2',
#  '4,6',
#  '--',
#  '2,8',
#  '4,6',
#  '--',
#  '5,0',
#  '4,6',
#  '--',
#  '4,6',
#  '4,5',
#  '--',
#  '3,2',
#  '4,5',
#  '--',
#  '3,8',
#  '4,5',
#  '--',
#  '3,4',
#  '4,5',
#  '--',
#  '5,0',
#  '4,5',
#  '--',
#  '4,0',
#  '4,5',
#  '--']

# %%
# we initialize an empty list for all data we want to scrap
all_title = []
all_release_date = []
all_director = []
all_duration = []
all_category = []
all_actor = []
all_resume = []
all_press_rating = []
all_spectator_rating = []
all_friend_rating = []

# %%
# on déclare l'url de la page 1
# url = 'https://www.allocine.fr/film/meilleurs/'
url ='https://www.allocine.fr/film/meilleurs/?page=30'
response = requests.get(url) 
soup=BeautifulSoup(response.text,'html.parser')

movies_card = soup.find_all('div',{"class":"card entity-card entity-card-list cf"})

# %%
for movie_card in movies_card :
    ## to extract mmovie title
    title_tag = movie_card.find_all("a",{"class":"meta-title-link"})
    title = title_tag[0].get_text()
    print("title : ",title)
    ## To extract release date
    release_date_tag = movie_card.find_all("span",{"class":"date"})
    # We check if the release_date_tag is empty because there are some movies without release_date
    if release_date_tag:
        release_date = release_date_tag[0].get_text()
    else:
        release_date = np.nan
    print("release_date : ",release_date)
    ## Extract duration and director
    director_tag = movie_card.find_all("a",{"class":"blue-link"})
    # We check if the director_tag is empty because there are some movies without director_tag
    if director_tag:
        director = director_tag[0].get_text()
    else:
        director = np.nan
    print("Director : ",director)
    ## Extract duration and categories
    duration_cat_tag = movie_card.find_all("div",{"class":"meta-body-item meta-body-info"})
    #print(duration_cat_tag)
    duration_cat = duration_cat_tag[0].get_text()
    #print("duration_cat : ",duration_cat)
    # We check if duration_cat is empty because there are some movies without duration_cat
    if duration_cat:
        duration, categories = duration_cat.split('/')
        duration = duration.strip('\n')
        categories_tag = duration_cat_tag[0].find_all("span")
        # to get category name in a list
        categories_name = [cat.get_text() for cat in categories_tag ]
        # to transform categories_name from list to string
        categories = categories_name[1]
        for i in range(2, len(categories_name)):
            categories += ',' + categories_name[i]
    else:
        duration = np.nan
        categories = np.nan
    print("duration : ",duration)
    print("categories : ", categories)
    ## Extract actors name
    actors_tag = movie_card.find_all("div",{"class":"meta-body-item meta-body-actor"})
    # We check if actors_tag is empty because there are some movies without actors_tag
    if actors_tag:
        actors_tag_list = actors_tag[0].find_all("a")
        # to get actors name in a list
        actors_name = [ element.get_text() for element in actors_tag_list]
        # to transform actors_name from list to string 
        actors = actors_name[0]
        for i in range(1,len(actors_name)):
            actors += ',' + actors_name[i]
    else:
        actors= np.nan
    print("actors : ",actors)
    ## to extract movie resume
    resume_tag = movie_card.find_all("div",{"class":"content-txt"})
    if resume_tag:
        resume = resume_tag[0].get_text()
        resume = resume.strip('\n')
    else:
        resume = np.nan
    print("resume : ",resume)
    ## to extract press_rate, spectator_rate and friend_rate
    rating_tag = movie_card.find_all("span",{"class":"stareval-note"})
    # We check if rating_tag is empty because there are some movies without rating_tag
    if rating_tag:
#         print(rating_tag)
        if len(rating_tag) == 3 :
            press_rating = rating_tag[0].get_text()
            spectator_rating = rating_tag[1].get_text()
            friends_rating = rating_tag[2].get_text()
        elif len(rating_tag) == 2 :
            press_rating = np.nan
            spectator_rating =  rating_tag[0].get_text()
            friends_rating = np.nan
    else:
        press_rating = np.nan
        spectator_rating =  np.nan
        friends_rating = np.nan
    print("press_rating : ",press_rating)
    print("spectator_rating : ",spectator_rating)
    print("friends_rating : ",friends_rating)
    all_title.append(title)
    all_release_date.append(release_date)
    all_director.append(director)
    all_duration.append(duration)
    all_category.append(categories)
    all_actor.append(actors)
    all_resume.append(resume)
    all_press_rating.append(press_rating)
    all_spectator_rating.append(spectator_rating)
    all_friend_rating.append(friends_rating)
    print("\n")
# Out:
# title :  Parvana
# release_date :  nan
# Director :  Nora Twomey
# duration :  1h 33min
# categories :  Animation,Famille
# actors :  Golshifteh Farahani,Saara Chaudry,Soma Bhatia
# resume :  En Afghanistan, sous le régime taliban, Parvana, onze ans, grandit à Kaboul ravagée par la guerre. Elle aime écouter les histoires que lui raconte son père, lecteur et écrivain public. Mais un jour, il est arrêté et la vie de Parvana bascule à jamais. Car sans être accompagnée d’un homme, on ne peut plus travailler, ramener de l'argent ni même acheter de la nourriture.
# press_rating :  4,1
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  HEIMAT II – L’exode
# release_date :  nan
# Director :  Edgar Reitz
# duration :  3h 51min
# categories :  Drame,Historique
# actors :  Jan Dieter Schneider,Antonia Bill,Maximilian Scheidt
# resume :  1842-1844, L’histoire de la famille Simon. Les coups du destin risquent de détruire cette famille mais c’est une histoire de courage et de foi en l’avenir.
# press_rating :  4,2
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Tout ce que le ciel permet
# release_date :  31 juillet 2019
# Director :  Douglas Sirk
# duration :  1h 29min
# categories :  Comédie dramatique,Romance
# actors :  Jane Wyman,Rock Hudson,Agnes Moorehead
# resume :  L'histoire d'une veuve qui renonce, à cause de sa famille, à refaire sa vie avec un homme plus jeune et d'une autre classe sociale que la sienne.
# press_rating :  5,0
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  L'Affaire Cicéron
# release_date :  6 novembre 2019
# Director :  Joseph L. Mankiewicz
# duration :   1h 48min
# categories :  Drame,Espionnage,Thriller
# actors :  James Mason,Danielle Darrieux,Michael Rennie
# resume :  En 1944, Diello sert un ambassadeur anglais à Ankara, en Turquie. Il en profite pour livrer des photographies de documents secrets alliés aux Nazis sous un nom de code : Cicéron. La comtesse polonaise Anna Staviska fait mine de l'aider...
# press_rating :  5,0
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Les Plus belles années de notre vie
# release_date :  20 novembre 2002
# Director :  William Wyler
# duration :  2h 52min
# categories :  Drame,Guerre
# actors :  Myrna Loy,Fredric March,Dana Andrews
# resume :  En 1945, trois soldats démobilisés font connaissance dans l'avion qui les ramène dans leur ville natale. Leurs sentiments sont partagés entre l'impatience et l'appréhension. Ils ne tardent pas à reprendre contact avec la réalité quotidienne...
# press_rating :  5,0
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  L'Ange ivre
# release_date :  17 avril 2019
# Director :  Akira Kurosawa
# duration :  1h 38min
# categories :  Drame,Thriller
# actors :  Toshirô Mifune,Takashi Shimura,Reisaburo Yamamoto
# resume :  Appelé en pleine nuit à soigner un jeune gangster pour une blessure à la main, un médecin alcoolique décèle une affection plus grave, la tuberculose. Il tente de soigner le jeune homme qui ne veut rien entendre, et malgré les disputes et les menaces, il se prend d'amitié pour lui.
# press_rating :  4,0
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Dans ses yeux
# release_date :  nan
# Director :  Juan José Campanella
# duration :  2h 09min
# categories :  Policier,Drame,Romance
# actors :  Ricardo Darín,Soledad Villamil,Pablo Rago
# resume :  1974, Buenos Aires. Benjamin Esposito enquête sur le meurtre violent d'une jeune femme. 25 ans plus tard, il décide d'écrire un roman basé sur cette affaire "classée" dont il a été témoin et protagoniste...
# press_rating :  3,6
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  La Chasse
# release_date :  nan
# Director :  Thomas Vinterberg
# duration :  1h 51min
# categories :  Drame
# actors :  Mads Mikkelsen,Thomas Bo Larsen,Annika Wedderkopp
# resume :  Après un divorce difficile, Lucas, quarante ans, a trouvé une nouvelle petite amie, un nouveau travail et il s'applique à reconstruire sa relation avec Marcus, son fils adolescent. Mais quelque chose tourne mal. Presque rien. Une remarque en passant. Un mensonge fortuit.
# press_rating :  3,1
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Snatch
# release_date :  nan
# Director :  Guy Ritchie
# duration :  1h 43min
# categories :  Comédie,Policier
# actors :  Jason Statham,Brad Pitt,Vinnie Jones
# resume :  Franky vient de voler un énorme diamant qu'il doit livrer à Avi, un mafieux new-yorkais. En chemin, il fait escale à Londres où il se laisse convaincre par Boris de parier sur un combat de boxe clandestin.
# press_rating :  3,7
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Bac Nord
# release_date :  nan
# Director :  Cédric Jimenez
# duration :  1h 44min
# categories :  Policier,Thriller
# actors :  Gilles Lellouche,François Civil,Karim Leklou
# resume :  2012. Les quartiers Nord de Marseille détiennent un triste record : la zone au taux de criminalité le plus élevé de France. Poussée par sa hiérarchie, la BAC Nord, brigade de terrain, cherche sans cesse à améliorer ses résultats.
# press_rating :  3,5
# spectator_rating :  4,2
# friends_rating :  --

# %%
movies_dict = {
    'title' : all_title,
     'release_date' : all_release_date,
    'director' : all_director,
    'duration' : all_duration,
    'category' : all_category,
    'actor' : all_actor,
    'resume' : all_resume,
    'press_rating' : all_press_rating,
    'spectator_rating' : all_spectator_rating,
    'friend_rating' : all_friend_rating
}

# %%
movies = pd.DataFrame(movies_dict)
print(movies.shape)
movies
# Out:
# (10, 10)
#                                  title      release_date  \
# 0                              Parvana               NaN
# 1                  HEIMAT II – L’exode               NaN
# 2           Tout ce que le ciel permet   31 juillet 2019
# 3                    L'Affaire Cicéron   6 novembre 2019
# 4  Les Plus belles années de notre vie  20 novembre 2002
# 5                          L'Ange ivre     17 avril 2019
# 6                        Dans ses yeux               NaN
# 7                            La Chasse               NaN
# 8                               Snatch               NaN
# 9                             Bac Nord               NaN
#
#                director   duration                    category  \
# 0           Nora Twomey   1h 33min           Animation,Famille
# 1           Edgar Reitz   3h 51min            Drame,Historique
# 2          Douglas Sirk   1h 29min  Comédie dramatique,Romance
# 3  Joseph L. Mankiewicz   1h 48min   Drame,Espionnage,Thriller
# 4         William Wyler   2h 52min                Drame,Guerre
# 5        Akira Kurosawa   1h 38min              Drame,Thriller
# 6  Juan José Campanella   2h 09min      Policier,Drame,Romance
# 7     Thomas Vinterberg   1h 51min                       Drame
# 8           Guy Ritchie   1h 43min            Comédie,Policier
# 9        Cédric Jimenez   1h 44min           Policier,Thriller
#
#                                                actor  \
# 0      Golshifteh Farahani,Saara Chaudry,Soma Bhatia
# 1  Jan Dieter Schneider,Antonia Bill,Maximilian S...
# 2             Jane Wyman,Rock Hudson,Agnes Moorehead
# 3       James Mason,Danielle Darrieux,Michael Rennie
# 4               Myrna Loy,Fredric March,Dana Andrews
# 5  Toshirô Mifune,Takashi Shimura,Reisaburo Yamamoto
# 6          Ricardo Darín,Soledad Villamil,Pablo Rago
# 7  Mads Mikkelsen,Thomas Bo Larsen,Annika Wedderkopp
# 8               Jason Statham,Brad Pitt,Vinnie Jones
# 9       Gilles Lellouche,François Civil,Karim Leklou
#
#                                               resume press_rating  \
# 0  En Afghanistan, sous le régime taliban, Parvan...          4,1
# 1  1842-1844, L’histoire de la famille Simon. Les...          4,2
# 2  L'histoire d'une veuve qui renonce, à cause de...          5,0
# 3  En 1944, Diello sert un ambassadeur anglais à ...          5,0
# 4  En 1945, trois soldats démobilisés font connai...          5,0
# 5  Appelé en pleine nuit à soigner un jeune gangs...          4,0
# 6  1974, Buenos Aires. Benjamin Esposito enquête ...          3,6
# 7  Après un divorce difficile, Lucas, quarante an...          3,1
# 8  Franky vient de voler un énorme diamant qu'il ...          3,7
# 9  2012. Les quartiers Nord de Marseille détienne...          3,5
#
#   spectator_rating friend_rating
# 0              4,2            --
# 1              4,2            --
# 2              4,2            --
# 3              4,2            --
# 4              4,2            --
# 5              4,2            --
# 6              4,2            --
# 7              4,2            --
# 8              4,2            --
# 9              4,2            --

# %% [markdown]
# ### Now,  we can generalize our process and collect data on all the other pages
# >Now that we have all the data on the movies on the first page, we can generalize and collect data on all the other pages

# %%
#create a function to generate the link of all the other page
# Note that we have created this function based on the structure of the urls of other pages
def create_link(urls):
    for i in range(2,31):
        urls.append(f'https://www.allocine.fr/film/meilleurs/?page={i}')
    return urls

# %%
# we initialize our list with the link of the fisrt page
urls=[
    'https://www.allocine.fr/film/meilleurs/',
]
links =create_link(urls)
print(len(links))
links
# Out:
# 30
# ['https://www.allocine.fr/film/meilleurs/',
#  'https://www.allocine.fr/film/meilleurs/?page=2',
#  'https://www.allocine.fr/film/meilleurs/?page=3',
#  'https://www.allocine.fr/film/meilleurs/?page=4',
#  'https://www.allocine.fr/film/meilleurs/?page=5',
#  'https://www.allocine.fr/film/meilleurs/?page=6',
#  'https://www.allocine.fr/film/meilleurs/?page=7',
#  'https://www.allocine.fr/film/meilleurs/?page=8',
#  'https://www.allocine.fr/film/meilleurs/?page=9',
#  'https://www.allocine.fr/film/meilleurs/?page=10',
#  'https://www.allocine.fr/film/meilleurs/?page=11',
#  'https://www.allocine.fr/film/meilleurs/?page=12',
#  'https://www.allocine.fr/film/meilleurs/?page=13',
#  'https://www.allocine.fr/film/meilleurs/?page=14',
#  'https://www.allocine.fr/film/meilleurs/?page=15',
#  'https://www.allocine.fr/film/meilleurs/?page=16',
#  'https://www.allocine.fr/film/meilleurs/?page=17',
#  'https://www.allocine.fr/film/meilleurs/?page=18',
#  'https://www.allocine.fr/film/meilleurs/?page=19',
#  'https://www.allocine.fr/film/meilleurs/?page=20',
#  'https://www.allocine.fr/film/meilleurs/?page=21',
#  'https://www.allocine.fr/film/meilleurs/?page=22',
#  'https://www.allocine.fr/film/meilleurs/?page=23',
#  'https://www.allocine.fr/film/meilleurs/?page=24',
#  'https://www.allocine.fr/film/meilleurs/?page=25',
#  'https://www.allocine.fr/film/meilleurs/?page=26',
#  'https://www.allocine.fr/film/meilleurs/?page=27',
#  'https://www.allocine.fr/film/meilleurs/?page=28',
#  'https://www.allocine.fr/film/meilleurs/?page=29',
#  'https://www.allocine.fr/film/meilleurs/?page=30']

# %%
links2 = ['https://www.allocine.fr/film/meilleurs/',
 'https://www.allocine.fr/film/meilleurs/?page=2']

# %%
print(len(links))
# Out:
# 30

# %%
# # we re-initialize an empty list for all data we want to scrap because now, we want to run this for all the page
# all_title = []
# all_release_date = []
# all_director = []
# all_duration = []
# all_category = []
# all_actor = []
# all_resume = []
# all_press_rating = []
# all_spectator_rating = []
# all_friend_rating = []

# %%
def scrap_movie_data(urls):
    ## we re-initialize an empty list for all data we want to scrap because now, we want to run this for all the page
    all_title = []
    all_release_date = []
    all_director = []
    all_duration = []
    all_category = []
    all_actor = []
    all_resume = []
    all_press_rating = []
    all_spectator_rating = []
    all_friend_rating = []
    
    for url in urls:
        ## Send a request to get the web page
        response = requests.get(url) 
        ## use BeautifulSoup to  read the page
        soup=BeautifulSoup(response.text,'html.parser')
        # Get all the movies card af the current page
        movies_card = soup.find_all('div',{"class":"card entity-card entity-card-list cf"})
        # to collect data movie by movie
        for movie_card in movies_card :
            ## to extract mmovie title
            title_tag = movie_card.find_all("a",{"class":"meta-title-link"})
            title = title_tag[0].get_text()
            print("title : ",title)
            ## To extract release date
            release_date_tag = movie_card.find_all("span",{"class":"date"})
            # We check if the release_date_tag is empty because there are some movies without release_date
            if release_date_tag:
                release_date = release_date_tag[0].get_text()
            else:
                release_date = np.nan
            print("release_date : ",release_date)
            ## Extract duration and director
            director_tag = movie_card.find_all("a",{"class":"blue-link"})
            # We check if the director_tag is empty because there are some movies without director_tag
            if director_tag:
                director = director_tag[0].get_text()
            else:
                director = np.nan
            print("Director : ",director)
            ## Extract duration and categories
            duration_cat_tag = movie_card.find_all("div",{"class":"meta-body-item meta-body-info"})
            #print(duration_cat_tag)
            duration_cat = duration_cat_tag[0].get_text()
            #print("duration_cat : ",duration_cat)
            # We check if duration_cat is empty because there are some movies without duration_cat
            if duration_cat:
                try:
                    duration, categories = duration_cat.split('/')
                    duration = duration.strip('\n')
                    categories_tag = duration_cat_tag[0].find_all("span")
                    # to get category name in a list
                    categories_name = [cat.get_text() for cat in categories_tag ]
                    # to transform categories_name from list to string
                    categories = categories_name[1]
                    for i in range(2, len(categories_name)):
                        categories += ',' + categories_name[i]
                except(ValueError):
                    # Pour certains film comme "Baby Cart la saga" qui ont code html différents, on saute
#                     continue;
                    pass;
            else:
                duration = np.nan
                categories = np.nan
            print("duration : ",duration)
            print("categories : ", categories)
            ## Extract actors name
            actors_tag = movie_card.find_all("div",{"class":"meta-body-item meta-body-actor"})
            # We check if actors_tag is empty because there are some movies without actors_tag
            if actors_tag:
                actors_tag_list = actors_tag[0].find_all("a")
                if actors_tag_list:
                    # to get actors name in a list
                    actors_name = [ element.get_text() for element in actors_tag_list]
                    # to transform actors_name from list to string 
                    actors = actors_name[0]
                    for i in range(1,len(actors_name)):
                        actors += ',' + actors_name[i]
            else:
                actors= np.nan
            print("actors : ",actors)
            ## to extract movie resume
            resume_tag = movie_card.find_all("div",{"class":"content-txt"})
            if resume_tag:
                resume = resume_tag[0].get_text()
                resume = resume.strip('\n')
            else:
                resume = np.nan
            print("resume : ",resume)
            ## to extract press_rate, spectator_rate and friend_rate
            rating_tag = movie_card.find_all("span",{"class":"stareval-note"})
            # We check if rating_tag is empty because there are some movies without rating_tag
            if rating_tag:
        #         print(rating_tag)
                if len(rating_tag) == 3 :
                    press_rating = rating_tag[0].get_text()
                    spectator_rating = rating_tag[1].get_text()
                    friends_rating = rating_tag[2].get_text()
                elif len(rating_tag) == 2 :
                    press_rating = np.nan
                    spectator_rating =  rating_tag[0].get_text()
                    friends_rating = np.nan
            else:
                press_rating = np.nan
                spectator_rating =  np.nan
                friends_rating = np.nan
            print("press_rating : ",press_rating)
            print("spectator_rating : ",spectator_rating)
            print("friends_rating : ",friends_rating)
            ## Add the current mivie data to lists
            all_title.append(title)
            all_release_date.append(release_date)
            all_director.append(director)
            all_duration.append(duration)
            all_category.append(categories)
            all_actor.append(actors)
            all_resume.append(resume)
            all_press_rating.append(press_rating)
            all_spectator_rating.append(spectator_rating)
            all_friend_rating.append(friends_rating)
            
            print("\n")
    #
    print("all_title : ",len(all_title))
    movies_dict = {
        'title' : all_title,
         'release_date' : all_release_date,
        'director' : all_director,
        'duration' : all_duration,
        'category' : all_category,
        'actor' : all_actor,
        'resume' : all_resume,
        'press_rating' : all_press_rating,
        'spectator_rating' : all_spectator_rating,
        'friend_rating' : all_friend_rating
    }

    movies_df = pd.DataFrame(movies_dict)
    print(movies_df.shape)
    return movies_df

# %%
df = scrap_movie_data(links)
# df2 = scrap_movie_data(links2)
# Out:
# title :  Forrest Gump
# release_date :  28 octobre 2015
# Director :  Robert Zemeckis
# duration :  2h 20min
# categories :  Comédie,Drame,Romance
# actors :  Tom Hanks,Gary Sinise,Robin Wright
# resume :   Quelques décennies d'histoire américaine, des années 1940 à la fin du XXème siècle, à travers le regard et l'étrange odyssée d'un homme simple et pur, Forrest Gump.
# press_rating :  2,6
# spectator_rating :  4,6
# friends_rating :  --
#
#
# title :  La Liste de Schindler
# release_date :  13 mars 2019
# Director :  Steven Spielberg
# duration :  3h 15min
# categories :  Historique,Guerre
# actors :  Liam Neeson,Ben Kingsley,Ralph Fiennes
# resume :  Evocation des années de guerre d'Oskar Schindler, industriel autrichien rentré à Cracovie en 1939 avec les troupes allemandes. Il va, tout au long de la guerre, protéger des juifs en les faisant travailler dans sa fabrique.
# press_rating :  4,2
# spectator_rating :  4,6
# friends_rating :  --
#
#
# title :  La Ligne verte
# release_date :  nan
# Director :  Frank Darabont
# duration :  3h 09min
# categories :  Policier,Fantastique
# actors :  Michael Clarke Duncan,David Morse
# resume :  Paul Edgecomb, Gardien-chef du pénitencier de Cold Mountain en 1935, était chargé de veiller au bon déroulement des exécutions capitales. Parmi les prisonniers se trouvait un colosse du nom de John Coffey...
# press_rating :  2,8
# spectator_rating :  4,6
# friends_rating :  --
#
#
# title :  12 hommes en colère
# release_date :  25 juillet 2007
# Director :  Sidney Lumet
# duration :  1h 35min
# categories :  Drame
# actors :  Henry Fonda,Martin Balsam,John Fiedler
# resume :  Lors d'un procès, un juré émet l'hypothèse que l'homme qu'il doit juger n'est peut-être pas coupable. Il va tenter de convaincre les onze autres jurés.
# press_rating :  5,0
# spectator_rating :  4,6
# friends_rating :  --
#
#
# title :  Le Parrain
# release_date :  23 février 2022
# Director :  Francis Ford Coppola
# duration :  2h 55min
# categories :  Policier,Drame
# actors :  Marlon Brando,Al Pacino,James Caan
# resume :  En 1945, à New York, les Corleone sont une des cinq familles de la mafia. Don Vito Corleone marie sa fille à un bookmaker. Sollozzo, "parrain" de la famille Tattaglia, propose à Don Vito une association dans le trafic de drogue...
# press_rating :  4,6
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Les Evadés
# release_date :  nan
# Director :  nan
# duration :  2h 22min
# categories :  Drame
# actors :  Tim Robbins,Morgan Freeman,Bob Gunton
# resume :  Condamné à perpétuité pour le meurtre de sa femme et de son amant, un banquier s'accroche à l'espoir et se lie d'amitié avec un autre détenu pour survivre en prison.
# press_rating :  3,2
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Le Seigneur des anneaux : le retour du roi
# release_date :  nan
# Director :  Peter Jackson
# duration :  3h 21min
# categories :  Aventure,Fantastique
# actors :  Sean Astin,Elijah Wood,Viggo Mortensen
# resume :  Tandis que les ténèbres se répandent sur la Terre du Milieu, Aragorn se révèle être l'héritier caché des rois antiques. Quant à Frodon, toujours tenté par l'Anneau, il voyage à travers les contrées ennemies, se reposant sur Sam et Gollum...
# press_rating :  3,8
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Le Roi Lion
# release_date :  11 avril 2012
# Director :  Roger Allers
# duration :  1h 29min
# categories :  Aventure,Animation,Musical
# actors :  Emmanuel Curtil,Matthew Broderick,Dimitri Rougeul
# resume :  Le long combat de Simba le lionceau pour accéder à son rang de roi des animaux, après que le fourbe Scar, son oncle, a tué son père et pris sa place.
# press_rating :  3,4
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Vol au-dessus d'un nid de coucou
# release_date :  16 septembre 2009
# Director :  Milos Forman
# duration :  2h 09min
# categories :  Drame
# actors :  Jack Nicholson,Louise Fletcher,William Redfield
# resume :  Rebellion dans un hôpital psychiatrique à l'instigation d'un malade qui se révolte contre la dureté d'une infirmière.
# press_rating :  5,0
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  The Dark Knight, Le Chevalier Noir
# release_date :  nan
# Director :  Christopher Nolan
# duration :  2h 32min
# categories :  Action,Thriller
# actors :  Christian Bale,Heath Ledger,Aaron Eckhart
# resume :  Batman entreprend de démanteler les dernières organisations criminelles de Gotham. Mais il se heurte bientôt à un nouveau génie du crime qui répand la terreur et le chaos dans la ville : le Joker...
# press_rating :  4,0
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Pulp Fiction
# release_date :  nan
# Director :  Quentin Tarantino
# duration :  2h 29min
# categories :  Policier,Thriller
# actors :  John Travolta,Samuel L. Jackson,Uma Thurman
# resume :  L'odyssée sanglante et burlesque de petits malfrats dans la jungle de Hollywood à travers trois histoires qui s'entremêlent.
# press_rating :  4,4
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Il était une fois dans l'Ouest
# release_date :  10 octobre 2018
# Director :  Sergio Leone
# duration :  2h 55min
# categories :  Western
# actors :  Henry Fonda,Charles Bronson,Frank Wolff
# resume :  Un mystérieux desperado pourchasse sans relâche un dangereux criminel.
# press_rating :  4,0
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Le Bon, la brute et le truand
# release_date :  5 novembre 2014
# Director :  nan
# duration :  3h 00min
# categories :  Western
# actors :  Clint Eastwood,Eli Wallach,Lee Van Cleef
# resume :  Pendant la Guerre de Sécession, Tuco, Joe et Setenza, trois hommes préférant s'intéresser à leur profit personnel, se lancent à la recherche d'un coffre contenant 200 000 dollars en pièces d'or volés à l'armée sudiste. Chacun a besoin de l'autre...
# press_rating :  4,1
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Il était une fois en Amérique
# release_date :  6 mai 2015
# Director :  nan
# duration :  3h 40min
# categories :  Policier,Drame
# actors :  Robert De Niro,James Woods,Elizabeth McGovern
# resume :  Il était une fois deux truands juifs, Max et Noodles, liés par un pacte d'éternelle amitié. Débutant au début du siècle par de fructueux trafics dans le ghetto de New York, ils voient leurs chemins se séparer, lorsque Noodles se retrouve durant quelques années derrière les barreaux, puis se recouper en pleine période de prohibition, dans les années vingt. Jusqu'au jour où la trahison les sépare à nouveau.
# press_rating :  4,9
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Django Unchained
# release_date :  nan
# Director :  nan
# duration :  2h 44min
# categories :  Western
# actors :  Jamie Foxx,Christoph Waltz,Leonardo DiCaprio
# resume :  Le parcours d'un chasseur de prime allemand et d'un homme noir pour retrouver la femme de ce dernier retenue en esclavage par le propriétaire d'une plantation...
# press_rating :  4,6
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Le Seigneur des anneaux : la communauté de l'anneau
# release_date :  nan
# Director :  Peter Jackson
# duration :  2h 58min
# categories :  Aventure,Fantastique
# actors :  Elijah Wood,Sean Astin,Ian McKellen
# resume :  Frodon le Hobbit hérite de l'Anneau Unique, un instrument de pouvoir absolu qui permettrait à Sauron, le Seigneur des ténèbres, de régner sur la Terre du Milieu. Commence alors un vaste périple visant à la destruction de l'objet.
# press_rating :  3,7
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Gladiator
# release_date :  nan
# Director :  Ridley Scott
# duration :  2h 35min
# categories :  Action,Aventure
# actors :  Russell Crowe,Joaquin Phoenix,Connie Nielsen
# resume :  Le général romain Maximus est le plus fidèle soutien de l'empereur Marc Aurèle, qu'il a conduit de victoire en victoire avec une bravoure et un dévouement exemplaires. Jaloux du prestige de Maximus, et plus encore de l'amour que lui voue l'empereur, le fils de MarcAurèle, Commode, s'arroge brutalement le pouvoir, puis ordonne l'arrestation du ...
# press_rating :  4,3
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Gran Torino
# release_date :  nan
# Director :  nan
# duration :  1h 56min
# categories :  Drame,Thriller
# actors :  Bee Vang,Ahney Her
# resume :  Walt Kowalski est un ancien de la guerre de Corée, un homme inflexible, amer et pétri de préjugés surannés. Hormis sa chienne Daisy, il ne fait confiance qu'à son M-1, toujours propre, toujours prêt à l'usage...
# press_rating :  4,7
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  
0
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Parasite
# release_date :  nan
# Director :  Bong Joon Ho
# duration :  2h 12min
# categories :  Thriller
# actors :  Song Kang-Ho,Woo-sik Choi,Park So-Dam
# resume :  Toute la famille de Ki-taek est au chômage, et s’intéresse fortement au train de vie de la richissime famille Park. Un jour, leur fils réussit à se faire recommander pour donner des cours particuliers d’anglais chez les Park. C’est le début d’un engrenage incontrôlable...
# press_rating :  4,8
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Les Affranchis
# release_date :  nan
# Director :  Martin Scorsese
# duration :  2h 25min
# categories :  Drame,Thriller
# actors :  Ray Liotta,Robert De Niro,Joe Pesci
# resume :  Depuis sa plus tendre enfance, Henry Hill, né d'un père irlandais et d'une mère sicilienne, veut devenir gangster et appartenir à la Mafia. Adolescent dans les années cinquante, il commence par travailler pour le compte de Paul Cicero...
# press_rating :  5,0
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Fight Club
# release_date :  15 mai 2019
# Director :  nan
# duration :  2h 19min
# categories :  Drame,Thriller
# actors :  Edward Norton,Helena Bonham Carter
# resume :  Le narrateur, vit seul, travaille seul, dort seul, comme beaucoup d'autres personnes seules qui connaissent la misère morale et sexuelle. C'est pourquoi il va devenir membre du Fight club, un lieu clandestin dirigé par Tyler Durden, anarchiste entre gourou et philosophe.
# press_rating :  2,7
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Le Parrain, 2e partie
# release_date :  18 septembre 2013
# Director :  Francis Ford Coppola
# duration :  3h 20min
# categories :  Policier,Drame
# actors :  Kathleen Beller,Ignazio Pappalardo,Roman Coppola
# resume :  Depuis la mort de Don Vito Corleone, son fils Michael règne sur la famille. Amené à négocier avec la mafia juive, il perd le soutien de son lieutenant Frankie Pentageli. Echappant de justesse à un attentat, Michael tente de retrouver le coupable...
# press_rating :  4,7
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Green Book : Sur les routes du sud
# release_date :  nan
# Director :  Peter Farrelly
# duration :  2h 10min
# categories :  Biopic,Drame
# actors :  Viggo Mortensen,Mahershala Ali,Linda Cardellini
# resume :  En 1962, alors que règne la ségrégation, Tony Lip, un videur italo-américain du Bronx, est engagé pour conduire et protéger le Dr Don Shirley, un pianiste noir de renommée mondiale, lors d’une tournée de concerts.
# press_rating :  4,0
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Inception
# release_date :  12 août 2020
# Director :  Christopher Nolan
# duration :  2h 28min
# categories :  Science Fiction,Thriller
# actors :  Leonardo DiCaprio,Marion Cotillard,Elliot Page
# resume :  Au lieu de subtiliser un rêve, un voleur expérimenté et son équipe doivent faire l'inverse : implanter une idée dans l'esprit d'un individu. S'ils y parviennent, il pourrait s'agir du crime parfait ...
# press_rating :  4,1
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  Retour vers le futur
# release_date :  nan
# Director :  Robert Zemeckis
# duration :  1h 56min
# categories :  Aventure,Comédie,Science Fiction
# actors :  Michael J. Fox,Christopher Lloyd,Lea Thompson
# resume :  Après être arrivé en 1955 à bord d'une DeLorean convertie en machine à remonter le temps, Marty McFly fonce pour s'assurer que ses futurs parents tombent amoureux.
# press_rating :  3,6
# spectator_rating :  4,5
# friends_rating :  --
#
#
# title :  La Vie est belle
# release_date :  nan
# Director :  Roberto Benigni
# duration :  1h 57min
# categories :  Comédie,Drame
# actors :  Horst Buchholz,Marisa Paredes
# resume :  En 1938, Guido, jeune homme plein de gaieté, rêve d'ouvrir une librairie, malgré les tracasseries de l'administration fasciste. Il tombe amoureux de Dora, institutrice étouffée par le conformisme familial et l'enlève le jour de ses fiançailles avec un bureaucrate du régime. Cinq ans plus tard, Guido et Dora ont un fils: Giosue. Mais les ...
# press_rating :  3,7
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Usual Suspects
# release_date :  18 juillet 2001
# Director :  Bryan Singer
# duration :  1h 46min
# categories :  Policier,Thriller
# actors :  Chazz Palminteri,Kevin Spacey,Gabriel Byrne
# resume :  Suite à une mystérieuse dénonciation, cinq criminels se retrouvent en garde à vue. Plus tard, engagés sur un coup par le génie du crime Keyser Söze, les cinq hommes sont pris au piège d’une diabolique machination…
# press_rating :  4,6
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Les Temps modernes
# release_date :  10 juillet 2019
# Director :  Charles Chaplin
# duration :  1h 27min
# categories :  Comédie dramatique,Romance
# actors :  Paulette Goddard,Henry Bergman
# resume :  Charlot est ouvrier dans une immense usine. Il resserre quotidiennement des boulons. Mais les machines, le travail à la chaîne le rendent malade, il abandonne son poste et recueille une orpheline…
# press_rating :  4,6
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Le Kid
# release_date :  10 juillet 2019
# Director :  nan
# duration :  0h 52min
# categories :  Comédie
# actors :  Jackie Coogan,Edna Purviance
# resume :  Lâchée par son amant, une jeune femme abandonne son enfant. Charlot le vagabond le recueille. Mais les services sociaux s’en mêlent...
# press_rating :  4,0
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Le Tombeau des lucioles
# release_date :  nan
# Director :  Isao Takahata
# duration :  1h 30min
# categories :  Animation,Drame,Guerre
# actors :  J. Robert Spencer,Ayano Shiraishi,Veronica Taylor
# resume :  Japon, été 1945. Après le bombardement de Kobé, Seita, un adolescent de quatorze ans et sa petite soeur de quatre ans, Setsuko, orphelins, vont s'installer chez leur tante à quelques dizaines de kilomètres de chez eux. Celle-ci leur fait comprendre qu'ils sont une gêne pour la famille et doivent mériter leur riz quotidien. Seita décide de ...
# press_rating :  4,0
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Whiplash
# release_date :  nan
# Director :  Damien Chazelle
# duration :  1h 47min
# categories :  Drame,Musical
# actors :  Miles Teller,J.K. Simmons,Paul Reiser
# resume :  Andrew, 19 ans, rêve de devenir l’un des meilleurs batteurs de jazz de sa génération. Mais la concurrence est rude au conservatoire de Manhattan où il s’entraîne avec acharnement...
# press_rating :  4,1
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  American History X
# release_date :  nan
# Director :  Tony Kaye
# duration :  1h 59min
# categories :  Drame
# actors :  Edward Norton,Edward Furlong,Elliott Gould
# resume :  Derek veut venger la mort de son père, abattu par un dealer noir, et épouse les thèses racistes d'un groupuscule de militants d'extrême droite. Ces théories le mèneront à commettre un double meurtre...
# press_rating :  2,8
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Psychose
# release_date :  6 avril 2022
# Director :  Alfred Hitchcock
# duration :  1h 49min
# categories :  Epouvante-horreur,Thriller
# actors :  Anthony Perkins,Janet Leigh,John Gavin
# resume :  Une jeune femme en fuite trouve refuge dans un motel isolé...
# press_rating :  4,5
# spectator_rating :  4,4
# friends_rating :  --
# title :  Le Silence des agneaux
# release_date :  7 octobre 2020
# Director :  Jonathan Demme
# duration :  1h 58min
# categories :  Drame,Thriller
# actors :  Anthony Hopkins,Jodie Foster,Scott Glenn
# resume :  Clarice Starling, jeune stagiaire du FBI, est désignée pour enquêter sur une série de meurtres épouvantables commis dans le Middle West par un tueur de femmes psychopathe connu sous le nom de Buffalo Bill.
# press_rating :  4,8
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  
8
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Les Sentiers de la gloire
# release_date :  23 mars 2011
# Director :  Stanley Kubrick
# duration :  1h 28min
# categories :  Drame,Guerre
# actors :  Kirk Douglas,Ralph Meeker,Adolphe Menjou
# resume :  Durant la Première Guerre mondiale, le général français Mireau lance une offensive suicidaire contre une position allemande imprenable. Au moment de l'attaque, les soldats tombent par dizaines et leurs compagnons refusent d'avancer...
# press_rating :  4,6
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Intouchables
# release_date :  nan
# Director :  Eric Toledano
# duration :  1h 52min
# categories :  Drame
# actors :  François Cluzet,Omar Sy,Anne Le Ny
# resume :  La rencontre improbable, touchante et drôle entre un riche aristocrate, tétraplégique depuis un accident de parapente, et un jeune de banlieue engagé par hasard pour être son aide à domicile...
# press_rating :  3,7
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Indiana Jones et la Dernière Croisade
# release_date :  nan
# Director :  Steven Spielberg
# duration :  2h 07min
# categories :  Action,Aventure
# actors :  Harrison Ford,Sean Connery,Denholm Elliott
# resume :  L'archéologue aventurier Indiana Jones se retrouve aux prises avec un maléfique milliardaire. Aux côtés de la cupide Elsa et de son père, il part à la recherche du Graal.
# press_rating :  4,4
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Le Pianiste
# release_date :  nan
# Director :  Roman Polanski
# duration :  2h 28min
# categories :  Drame,Historique
# actors :  Adrien Brody,Thomas Kretschmann,Emilia Fox
# resume :  Durant la Seconde Guerre mondiale, Wladyslaw Szpilman, un pianiste juif polonais, est interné dans le ghetto de Varsovie dont il partage les souffrances, les humiliations et les luttes héroïques. Un officier allemand l'aide et lui permet de survivre.
# press_rating :  4,1
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Spider-Man : New Generation
# release_date :  nan
# Director :  Bob Persichetti
# duration :  1h 57min
# categories :  Action,Animation,Famille
# actors :  Stéphane Bak,Shameik Moore,Jake Johnson (XVI)
# resume :  SPIDER-MAN : NEW GENERATION présente Miles Morales, un adolescent vivant à Brooklyn, et révèle les possibilités illimitées du Spider-Verse, un univers où plus d’un peut porter le masque…
# press_rating :  4,2
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Princesse Mononoké
# release_date :  nan
# Director :  nan
# duration :  2h 15min
# categories :  Animation,Drame
# actors :  Gillian Anderson,Claire Danes,Pamela Adlon
# resume :  Japon, XVe siècle. Jadis protégée par des animaux géants, la forêt se dépeuple à cause de l'homme. Blessé par un sanglier rendu fou par les démons, le jeune guerrier Ashitaka quitte les siens et part à la recherche du dieu-cerf qui seul pourra défaire le sortilège qui lui gangrène le bras. Au cours de son voyage, Ashitaka rencontre Lady Eboshi, à la tête d’une communauté de forgerons, qui doit se défendre contre ceux qui lui reprochent de détruire la forêt pour alimenter ses forges. Parmi ses pires ennemis se trouve San, une jeune fille sauvage élevée par des loups, aussi appelée "Princesse Mononoké", la princesse des spectres...
# press_rating :  4,8
# spectator_rating :  4,4
# friends_rating :  --
# title :  Ip Man
# release_date :  nan
# Director :  Wilson Yip
# duration :  1h 45min
# categories :  Biopic,Arts Martiaux
# actors :  Donnie Yen,Simon Yam,Siu-Wong Fan
# resume :  Film biographique sur la vie de Ip Man, pionnier du Wing Chun et maitre de Bruce Lee.
# press_rating :  nan
# spectator_rating :  4,4
# friends_rating :  nan
#
#
# title :  Il faut sauver le soldat Ryan
# release_date :  nan
# Director :  Steven Spielberg
# duration :  2h 43min
# categories :  Drame,Guerre
# actors :  Ryan Hurst,Tom Hanks,Tom Sizemore
# resume :  Alors que les forces alliées débarquent à Omaha Beach, Miller doit conduire son escouade derrière les lignes ennemies pour une mission particulièrement dangereuse : trouver et ramener sain et sauf le simple soldat James Ryan, dont les trois frères sont morts au combat en l'espace de trois jours. Pendant que l'escouade progresse en territoire ...
# press_rating :  3,0
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Top Gun: Maverick
# release_date :  nan
# Director :  Joseph Kosinski
# duration :  2h 11min
# categories :  Action
# actors :  Tom Cruise,Miles Teller,Jennifer Connelly
# resume :  Après avoir été l’un des meilleurs pilotes de chasse de la Marine américaine, Pete “Maverick" Mitchell continue à repousser ses limites en tant que pilote d'essai. Il est chargé de former un détachement de jeunes diplômés de l’école Top Gun pour une mission spéciale qu’aucun pilote n'aurait jamais imaginée.
# press_rating :  3,7
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Les Aventuriers de l'Arche perdue
# release_date :  nan
# Director :  nan
# duration :  1h 56min
# categories :  Action,Aventure
# actors :  Harrison Ford,Karen Allen,Paul Freeman
# resume :  1936. L'aventurier Indiana Jones est mandaté pour mettre la main sur le médaillon de Râ, qui serait le premier pas sur le chemin de l'Arche d'Alliance, celle-là même où Moïse conserva les Dix Commandements. Une pièce dont Hitler cherche aussi à s'emparer.
# press_rating :  4,6
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Matrix
# release_date :  nan
# Director :  Lana Wachowski
# duration :  2h 15min
# categories :  Action,Science Fiction
# actors :  Keanu Reeves,Laurence Fishburne,Carrie-Anne Moss
# resume :  Programmeur anonyme, Thomas Anderson est aussi l'un des pirates les plus recherchés du cyber-space. Il est contacté par un certain Morpheus. Ensemble, ils se lancent dans une lutte sans retour contre la Matrice et ses terribles agents...
# press_rating :  3,4
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Alien, le huitième passager
# release_date :  12 novembre 2003
# Director :  Ridley Scott
# duration :  1h 56min
# categories :  Epouvante-horreur,Science Fiction
# actors :  Sigourney Weaver,Tom Skerritt,Veronica Cartwright
# resume :  Le vaisseau Nostromo et son équipage rentrent sur Terre avec une cargaison de minerai. Mais lors d'un arrêt forcé sur une planète déserte, l'officier Kane se fait agresser par une forme de vie inconnue, une arachnide qui étouffe son visage...
# press_rating :  4,4
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Toy Story 3
# release_date :  nan
# Director :  Lee Unkrich
# duration :  1h 40min
# categories :  Aventure,Animation,Comédie
# actors :  Jean-Philippe Puymartin,Richard Darbois
# resume :  Woody le cowboy, Buzz l'Eclair et les autres jouets se retrouvent confrontés à ce qui devait bien arriver un jour : le départ d'Andy pour l'université...
# press_rating :  4,7
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Le Conte de la princesse Kaguya
# release_date :  nan
# Director :  Isao Takahata
# duration :  2h 17min
# categories :  Animation,Drame,Famille
# actors :  Aki Asakura,Kengo Kora,Takeo Chii
# resume :  Kaguya, « la princesse lumineuse », est un petit être découvert dans la tige d’un bambou par un vieux paysan. La considérant comme un don du ciel, il l’élève avec sa femme, et très vite l’enfant devient une magnifique jeune fille. De la campagne lointaine jusqu’à la grande capitale, sa fascinante beauté suscitera l’engouement auprès de tous ceux qui la rencontrent et elle sera convoitée par cinq nobles princes qui devront relever d’impossibles défis dans l’espoir d’obtenir sa main. Mais le temps venu, elle devra affronter son destin…
# press_rating :  4,5
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  
0
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Elephant Man
# release_date :  22 juin 2020
# Director :  David Lynch
# duration :  2h 05min
# categories :  Biopic,Drame
# actors :  Anthony Hopkins,John Hurt,Anne Bancroft
# resume :  Londres, 1884. Le chirurgien Frederick Treves découvre un homme complètement défiguré et difforme, devenu une attraction de foire. John Merrick, " le monstre ", doit son nom de Elephant Man au terrible accident que subit sa mère.
# press_rating :  4,8
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Edward aux mains d'argent
# release_date :  nan
# Director :  Tim Burton
# duration :  1h 45min
# categories :  Comédie,Fantastique,Romance
# actors :  Johnny Depp,Winona Ryder,Dianne Wiest
# resume :  Edward Scissorhands n'est pas un garcon ordinaire. Création d'un inventeur, il a recu un coeur pour aimer, un cerveau pour comprendre. Mais son concepteur est mort avant d'avoir pu terminer son oeuvre...
# press_rating :  4,4
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Barry Lyndon
# release_date :  19 décembre 2007
# Director :  nan
# duration :  3h 07min
# categories :  Aventure,Drame
# actors :  Ryan O'Neal,Marisa Berenson,Patrick Magee
# resume :  De l'Irlande à la Prusse, l'histoire d'un jeune intriguant et de son ascension dans la fastueuse société du XVIIIème siècle...
# press_rating :  5,0
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Sueurs froides
# release_date :  19 mai 2004
# Director :  Alfred Hitchcock
# duration :  2h 09min
# categories :  Drame,Thriller
# actors :  James Stewart,Kim Novak,Barbara Bel Geddes
# resume :  Rendu responsable de la mort d'un collègue, Scottie, sujet au vertige, quitte la police. Une ancienne relation le contacte afin qu'il suive son épouse, possédée selon lui par l'esprit de son aïeule. Scottie s'éprend bientôt de la jeune femme.
# press_rating :  3,8
# spectator_rating :  4,4
# friends_rating :  --
#
#
# title :  Wall-E
# release_date :  nan
# Director :  Andrew Stanton
# duration :  1h 37min
# categories :  Aventure,Animation,Fantastique
# actors :  Ben Burtt,Elissa Knight,Jeff Garlin
# resume :  L'histoire d'un petit robot nommé WALL•E, à la recherche du grand amour sur Terre... et dans l'espace !
# press_rating :  4,6
# spectator_rating :  4,3
# friends_rating :  --
# title :  La Ruée vers l'or
# release_date :  10 juillet 2019
# Director :  Charles Chaplin
# duration :  1h 12min
# categories :  Comédie
# actors :  Mack Swain,Tom Murray
# resume :  1898, Nord-Ouest du Canada. Alors que des milliers d’aventuriers arpentent le Klondike en quête du métal précieux, Charlot est surpris par une tempête de neige. Il trouve refuge dans une cabane isolée et fait la rencontre de Big Jim McKay et du terrible Black Larsen…
# press_rating :  5,0
# spectator_rating :  4,3
# friends_rating :  --
#
#
# title :  Le Trou
# release_date :  19 avril 2017
# Director :  Jacques Becker
# duration :  2h 12min
# categories :  Drame,Thriller
# actors :  Michel Constantin,Jean Keraudy,Philippe Leroy
# resume :  Cinq prisonniers, enfermés à La Santé, vont tenter de s'évader en creusant un tunnel.
# press_rating :  nan
# spectator_rating :  4,3
# friends_rating :  nan
#
#
# title :  1917
# release_date :  nan
# Director :  Sam Mendes
# duration :  1h 59min
# categories :  Drame,Guerre
# actors :  George MacKay,Dean-Charles Chapman,Mark Strong
# resume :  Pris dans la tourmente de la Première Guerre Mondiale, Schofield et Blake, deux jeunes soldats britanniques, se voient assigner une mission à proprement parler impossible. Porteurs d’un message qui pourrait empêcher une attaque dévastatrice et la mort de centaines de soldats, dont le frère de Blake, ils se lancent dans une véritable course contre la montre, derrière les lignes ennemies.
# press_rating :  4,2
# spectator_rating :  4,3
# friends_rating :  --
#
#
# title :  
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Platoon
# release_date :  25 juillet 2018
# Director :  Oliver Stone
# duration :  2h 00min
# categories :  Drame,Guerre
# actors :  Charlie Sheen,Tom Berenger,Willem Dafoe
# resume :  Septembre 1967: Chris Taylor, dix-neuf ans, rejoint la compagnie Bravo du 25ème régiment d'infanterie, près de la frontière cambodgienne. Chris, issu d'une famille bourgeoise s'est engagé volontairement et, plein d'idéal entend bien servir son pays.
# press_rating :  4,6
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  The Revenant
# release_date :  nan
# Director :  Alejandro González Iñárritu
# duration :  2h 36min
# categories :  Aventure,Western
# actors :  Leonardo DiCaprio,Tom Hardy,Domhnall Gleeson
# resume :  Dans une Amérique profondément sauvage, Hugh Glass, un trappeur, est attaqué par un ours et grièvement blessé. Abandonné par ses équipiers, il est laissé pour mort. Mais Glass refuse de mourir.
# press_rating :  3,8
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Le Nom de la Rose
# release_date :  nan
# Director :  Jean-Jacques Annaud
# duration :  2h 11min
# categories :  Aventure,Policier,Drame
# actors :  Sean Connery,Christian Slater,Helmut Qualtinger
# resume :  En l'an 1327, dans une abbaye bénédictine, des moines disparaissent. Un franciscain, Guillaume de Baskerville aidé du jeune novice Adso von Melk mène l'enquête. C'est l'époque où l'Eglise, en pleine crise, se voit disputer son pouvoir spirituel et temporel. C'est aussi l'apogée de l'inquisition. Un thriller moyenageux très attendu ...
# press_rating :  4,8
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Little Big Man
# release_date :  20 juillet 2016
# Director :  Arthur Penn
# duration :  2h 19min
# categories :  Aventure,Western
# actors :  Dustin Hoffman,Faye Dunaway,Martin Balsam
# resume :  L'histoire d'un visage pâle partagé entre ses origines et sa famille d'adoption, indienne.
# press_rating :  nan
# spectator_rating :  4,2
# friends_rating :  nan
#
#
# title :  La La Land
# release_date :  nan
# Director :  Damien Chazelle
# duration :  2h 08min
# categories :  Comédie musicale,Romance
# actors :  Ryan Gosling,Emma Stone,John Legend
# resume :  Au cœur de Los Angeles, une actrice en devenir prénommée Mia sert des cafés entre deux auditions. De son côté, Sebastian, passionné de jazz, joue du piano dans des clubs miteux pour assurer sa subsistance. Tous deux sont bien loin de la vie rêvée à laquelle ils aspirent…
# press_rating :  4,4
# spectator_rating :  4,2
# friends_rating :  --
# title :  Call Me By Your Name
# release_date :  nan
# Director :  Luca Guadagnino
# duration :  2h 11min
# categories :  Drame,Romance
# actors :  Armie Hammer,Timothée Chalamet,Michael Stuhlbarg
# resume :  Été 1983. Elio Perlman, 17 ans, passe ses vacances dans la villa du XVIIe siècle que possède sa famille en Italie, à jouer de la musique classique, à lire et à flirter avec son amie Marzia. Son père, éminent professeur spécialiste de la culture gréco-romaine, et sa mère, traductrice, lui ont donné une excellente éducation, et il est proche de ses parents.
# press_rating :  4,2
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  The Greatest Showman
# release_date :  nan
# Director :  Michael Gracey
# duration :  1h 44min
# categories :  Drame,Comédie musicale
# actors :  Hugh Jackman,Zac Efron,Michelle Williams
# resume :  L’histoire de P.T Barnum, un visionnaire parti de rien pour créer un spectacle devenu un phénomène planétaire.
# press_rating :  2,7
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  La grande illusion
# release_date :  15 février 2012
# Director :  Jean Renoir
# duration :  1h 54min
# categories :  Drame,Guerre
# actors :  Jean Gabin,Dita Parlo,Erich Von Stroheim
# resume :  Première Guerre mondiale. Deux soldats français sont faits prisonniers par le commandant von Rauffenstein, un Allemand raffiné et respectueux. Conduits dans un camp de prisonniers, ils aident leurs compagnons de chambrée à creuser un tunnel secret.
# press_rating :  5,0
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Les Raisins de la colère
# release_date :  23 janvier 2019
# Director :  John Ford
# duration :  2h 09min
# categories :  Drame
# actors :  Henry Fonda,Jane Darwell,John Carradine
# resume :  Expropriée de ses terres, une famille de fermiers traverse les Etats-Unis à la recherche d'un emploi. Mais dans ces années de crise, ils ne rencontrent que spoliation et injustice.
# press_rating :  4,8
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Requiem for a Dream
# release_date :  nan
# Director :  Darren Aronofsky
# duration :  1h 42min
# categories :  Drame
# actors :  Jared Leto,Ellen Burstyn,Jennifer Connelly
# resume :  Harry Goldfarb est un junkie. Il passe ses journées en compagnie de sa petite amie Marion et son copain Tyrone. Ensemble, ils s'inventent un paradis artificiel. En quête d'une vie meilleure, le trio est entraîné dans une spirale infernale...
# press_rating :  4,0
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Sorcerer
# release_date :  15 juillet 2015
# Director :  William Friedkin
# duration :  2h 01min
# categories :  Action,Aventure,Drame
# actors :  Roy Scheider,Bruno Cremer,Francisco Rabal
# resume :  Quatre étrangers de nationalités différentes, chacun recherché dans son pays, s'associent pour conduire un chargement de nitroglycérine à travers la jungle sud-américaine… Un voyage au coeur des ténèbres…
# press_rating :  nan
# spectator_rating :  4,2
# friends_rating :  nan
#
#
# title :  Une Place au soleil
# release_date :  1 mai 2013
# Director :  George Stevens
# duration :  2h 02min
# categories :  Drame,Romance
# actors :  Montgomery Clift,Elizabeth Taylor,Shelley Winters
# resume :  George est engagé dans l'entreprise de son oncle Eastman. Il devient l'amant d'une ouvrière, Alice, puis rencontre Angela Vickers, une jeune bourgeoise qui s'éprend de lui.
# press_rating :  5,0
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Bienvenue à Gattaca
# release_date :  nan
# Director :  Andrew Niccol
# duration :  1h 46min
# categories :  Science Fiction
# actors :  Ethan Hawke,Uma Thurman,Jude Law
# resume :  Dans un monde parfait, Gattaca est un centre d'études et de recherches spatiales pour des jeunes gens au patrimoine génétique impeccable. Jérôme, candidat idéal, voit sa vie détruite par un accident...
# press_rating :  nan
# spectator_rating :  4,2
# friends_rating :  nan
#
#
# title :  Toy Story 4
# release_date :  nan
# Director :  Josh Cooley
# duration :  1h 40min
# categories :  Aventure,Animation,Comédie
# actors :  Jean-Philippe Puymartin,Tom Hanks,Richard Darbois
# resume :  Woody a toujours privilégié la joie de ses jeunes propriétaires – Andy puis Bonnie – et de ses compagnons, n’hésitant pas à prendre tous les risques pour eux, aussi inconsidérés soient-ils. L’arrivée de Fourchette un nouveau jouet qui ne veut pas en être un met toute la petite bande en émoi.
# press_rating :  4,2
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  La Chasse
# release_date :  nan
# Director :  Thomas Vinterberg
# duration :  1h 51min
# categories :  Drame
# actors :  Mads Mikkelsen,Thomas Bo Larsen,Annika Wedderkopp
# resume :  Après un divorce difficile, Lucas, quarante ans, a trouvé une nouvelle petite amie, un nouveau travail et il s'applique à reconstruire sa relation avec Marcus, son fils adolescent. Mais quelque chose tourne mal. Presque rien. Une remarque en passant. Un mensonge fortuit.
# press_rating :  3,1
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Snatch
# release_date :  nan
# Director :  Guy Ritchie
# duration :  1h 43min
# categories :  Comédie,Policier
# actors :  Jason Statham,Brad Pitt,Vinnie Jones
# resume :  Franky vient de voler un énorme diamant qu'il doit livrer à Avi, un mafieux new-yorkais. En chemin, il fait escale à Londres où il se laisse convaincre par Boris de parier sur un combat de boxe clandestin.
# press_rating :  3,7
# spectator_rating :  4,2
# friends_rating :  --
#
#
# title :  Bac Nord
# release_date :  nan
# Director :  Cédric Jimenez
# duration :  1h 44min
# categories :  Policier,Thriller
# actors :  Gilles Lellouche,François Civil,Karim Leklou
# resume :  2012. Les quartiers Nord de Marseille détiennent un triste record : la zone au taux de criminalité le plus élevé de France. Poussée par sa hiérarchie, la BAC Nord, brigade de terrain, cherche sans cesse à améliorer ses résultats.
# press_rating :  3,5
# spectator_rating :  4,2
# friends_rating :  --
#
#
# all_title :  300
# (300, 10)

# %%
df.shape
# Out:
# (300, 10)

# %%
df.sample(5)
# Out:
#                        title     release_date               director  \
# 142  Retour vers le futur II              NaN        Robert Zemeckis
# 201        Illusions Perdues              NaN        Xavier Giannoli
# 169                    Ordet  9 novembre 2022    Carl Theodor Dreyer
# 46                  Hamilton              NaN            Thomas Kail
# 272    Le Salaire de la Peur  8 novembre 2017  Henri-Georges Clouzot
#
#      duration                          category  \
# 142  1h 48min  Aventure,Comédie,Science Fiction
# 201  2h 30min                  Drame,Historique
# 169  2h 06min                             Drame
# 46   2h 40min         Biopic,Historique,Musical
# 272  2h 31min                 Aventure,Thriller
#
#                                                  actor  \
# 142      Michael J. Fox,Christopher Lloyd,Lea Thompson
# 201   Benjamin Voisin,Cécile de France,Vincent Lacoste
# 169  Henrik Malberg,Emil Hass Christensen,Preben Le...
# 46   Lin-Manuel Miranda,Jonathan Groff (II),Daveed ...
# 272          Yves Montand,Charles Vanel,Peter van Eyck
#
#                                                 resume press_rating  \
# 142  Lors de son premier voyage en 1985, Marty a co...          1,6
# 201  Lucien est un jeune poète inconnu dans la Fran...          4,0
# 169  En 1930, dans un village du Jutland, des disco...          NaN
# 46   Captation de la célèbre comédie musicale de Br...          NaN
# 272  Quatre hommes acceptent de véhiculer, au péril...          NaN
#
#     spectator_rating friend_rating
# 142              4,3            --
# 201              4,3            --
# 169              4,3           NaN
# 46               4,4           NaN
# 272              4,2           NaN

# %%
df.to_csv('allocine_best_movies.csv',index=False)

# %% [markdown]
# ## All is ok ; Next, we are going to analyze collected data

# %%
df.duplicated().sum()
# Out:
# 0
